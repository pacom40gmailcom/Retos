# %%
import pandas as pd

# %%
pd.read_csv("./datos/beer_train.csv")
# Out:
#           Id  Size(L)     OG     FG   ABV     IBU  Color  BoilSize  BoilTime  \
# 0          0    22.71  1.071  1.021  6.51   81.14   6.43     28.39        90
# 1          1     7.57  1.062  1.016  6.14  138.44  15.28      7.57        60
# 2          2    12.00  1.051  1.012  5.17   27.57  14.54     14.00        60
# 3          3    15.00  1.051  1.013  5.01   38.53  26.73     19.00        90
# 4          4    21.77  1.061  1.013  6.25   43.20   4.08     23.66        15
# ...      ...      ...    ...    ...   ...     ...    ...       ...       ...
# 24061  24061    22.00  1.056  1.009  6.13   51.28   6.54     25.00        60
# 24062  24062     3.79  1.058  1.014  5.83   77.88   6.00      6.44        60
# 24063  24063    10.00  1.055  1.015  5.20   20.24  14.68     14.00        60
# 24064  24064    20.00  1.059  1.014  5.94   36.12  15.72     28.50        60
# 24065  24065    50.00  1.048  1.012  4.79   25.82   2.64     53.50        90
#
# ...
